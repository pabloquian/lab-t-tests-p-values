# %% [markdown]
# #  T-tests and P-values
#
# In statistics, t-test is used to test if two data samples have a significant difference between their means. There are two types of t-test:
#
# * **Student's t-test** (a.k.a. independent or uncorrelated t-test). This type of t-test is to compare the samples of **two independent populations** (e.g. test scores of students in two different classes). `scipy` provides the [`ttest_ind`](https://docs.scipy.org/doc/scipy-0.15.1/reference/generated/scipy.stats.ttest_ind.html) method to conduct student's t-test.
#
# * **Paired t-test** (a.k.a. dependent or correlated t-test). This type of t-test is to compare the samples of **the same population** (e.g. scores of different tests of students in the same class). `scipy` provides the [`ttest_rel`](https://docs.scipy.org/doc/scipy-0.15.1/reference/generated/scipy.stats.ttest_rel.html) method to conduct paired t-test.
#
# Both types of t-tests return a number which is called the **p-value**. If p-value is below 0.05, we can confidently declare the null-hypothesis is rejected and the difference is significant. If p-value is between 0.05 and 0.1, we may also declare the null-hypothesis is rejected but we are not highly confident. If p-value is above 0.1 we do not reject the null-hypothesis.
#
# Read more about the t-test in [this article](http://b.link/test50) and [this Quora](http://b.link/unpaired97). Make sure you understand when to use which type of t-test.

# %%
# Import libraries
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### One tailed t-test
# In a packing plant, a machine packs cartons with jars. It is supposed that a new machine will pack faster on the average than the machine currently used. To test that hypothesis, the times it takes each machine to pack ten cartons are recorded. The results, in seconds, are shown in the tables in the file files_for_lab/ttest_machine.xlsx. Assume that there is sufficient evidence to conduct the t test, does the data provide sufficient evidence to show if one machine is better than the other?

# %% [markdown]
# #### Import dataset

# %%
machine = pd.read_csv('ttest_machine.txt', sep=" ")
machine
# Out:
#    New_machine  Old_machine
# 0         42.1         42.7
# 1         41.0         43.6
# 2         41.3         43.8
# 3         41.8         43.3
# 4         42.4         42.5
# 5         42.8         43.5
# 6         43.2         43.1
# 7         42.3         41.7
# 8         41.8         44.0
# 9         42.7         44.1

# %%
# independent variables testing
# H0: mu_o - mu_n = 0
# H1: mu_o - mu_n != 0
# 5% significance

st.ttest_ind(machine.New_machine, machine.Old_machine, equal_var=False)# if we don't assume equal variance the test will be more robust
# Out:
# TtestResult(statistic=-3.3972307061176026, pvalue=0.00324224946631798, df=17.847298506720346)

# %%
# I reject H0 as pvalue is lower than my significance level of 0.05

# %% [markdown]
# #### Import dataset
#
# In this challenge we will work on the Pokemon dataset you have already used. The goal is to test whether different groups of pokemon (e.g. Legendary vs Normal, Generation 1 vs 2, single-type vs dual-type) have different stats (e.g. HP, Attack, Defense, etc.). Use pokemon.csv

# %%
pokemon = pd.read_csv('Pokemon.txt', sep=",")
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# #### First we want to define a function with which we can test the means of a feature set of two samples.
#
# In the next cell you'll see the annotations of the Python function that explains what this function does and its arguments and returned value. This type of annotation is called **docstring** which is a convention used among Python developers. The docstring convention allows developers to write consistent tech documentations for their codes so that others can read. It also allows some websites to automatically parse the docstrings and display user-friendly documentations.
#
# Follow the specifications of the docstring and complete the function.

# %%
def t_test_features(s1, s2, features=['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Total']):
    """Test means of a feature set of two samples
    
    Args:
        s1 (dataframe): sample 1
        s2 (dataframe): sample 2
        features (list): an array of features to test
    
    Returns:
        dict: a dictionary of t-test scores for each feature where the feature name is the key and the p-value is the value
    """
    results = {}

    # Your code here
    for i in features:
        results[i]=st.ttest_ind(s1[i], s2[i], equal_var=False)[1]
    
    return results

# %%
sample_1 = pokemon[pokemon.Legendary==True].sample(30)
sample_1
# Out:
#        #                      Name    Type 1    Type 2  Total   HP  Attack  \
# 539  482                     Azelf   Psychic       NaN    580   75     125
# 164  150       MewtwoMega Mewtwo Y   Psychic       NaN    780  106     150
# 414  377                  Regirock      Rock       NaN    580   80     100
# 541  484                    Palkia     Water    Dragon    680   90     120
# 710  646                    Kyurem    Dragon       Ice    660  125     130
# 415  378                    Regice       Ice       NaN    580   80      50
# 262  243                    Raikou  Electric       NaN    580   90      85
# 793  717                   Yveltal      Dark    Flying    680  126     131
# 429  386        DeoxysAttack Forme   Psychic       NaN    600   50     180
# 417  380                    Latias    Dragon   Psychic    600   80      80
# 711  646        KyuremBlack Kyurem    Dragon       Ice    700  125     170
# ...

# %%
sample_2 = pokemon[pokemon.Legendary==False].sample(30)
sample_2
# Out:
#        #                     Name    Type 1    Type 2  Total   HP  Attack  \
# 531  479                    Rotom  Electric     Ghost    440   50      50
# 698  637                Volcarona       Bug      Fire    550   85      60
# 250  231                   Phanpy    Ground       NaN    330   90      60
# 217  202                Wobbuffet   Psychic       NaN    405  190      33
# 1      2                  Ivysaur     Grass    Poison    405   60      62
# 734  666                 Vivillon       Bug    Flying    411   80      52
# 620  559                  Scraggy      Dark  Fighting    348   50      75
# 408  373                Salamence    Dragon    Flying    600   95     135
# 526  475                  Gallade   Psychic  Fighting    518   68     125
# 86    80                  Slowbro     Water   Psychic    490   95      75
# 472  425                 Drifloon     Ghost    Flying    348   90      50
# 87    80      SlowbroMega Slowbro     Water   Psychic    590   95      75
# ...

# %% [markdown]
# #### Using the `t_test_features` function, conduct t-test for Lengendary vs non-Legendary pokemons.
#
# *Hint: your output should look like below:*
#
# ```
# {'HP': 1.0026911708035284e-13,
#  'Attack': 2.520372449236646e-16,
#  'Defense': 4.8269984949193316e-11,
#  'Sp. Atk': 1.5514614112239812e-21,
#  'Sp. Def': 2.2949327864052826e-15,
#  'Speed': 1.049016311882451e-18,
#  'Total': 9.357954335957446e-47}
#  ```

# %%
t_test_features(sample_1, sample_2)
# Out:
# {'HP': 0.08452570285641775,
#  'Attack': 3.5583313239949473e-07,
#  'Defense': 0.05632944728538141,
#  'Sp. Atk': 5.516093819076758e-07,
#  'Sp. Def': 0.0005434881970033057,
#  'Speed': 2.235294454516609e-07,
#  'Total': 5.132664806918583e-13}

# %% [markdown]
# #### From the test results above, what conclusion can you make? Do Legendary and non-Legendary pokemons have significantly different stats on each feature?

# %% [markdown]
#  I reject H0 in 5 of the 7 tested features, so I can say that by mean they do have different stats.

# %% [markdown]
# #### Next, conduct t-test for Generation 1 and Generation 2 pokemons.

# %%
sample_gen_1 = pokemon[pokemon.Generation==1].sample(30)
sample_gen_1
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 83    77                     Ponyta      Fire       NaN    410   50      85
# 133  124                       Jynx       Ice   Psychic    455   65      50
# 30    25                    Pikachu  Electric       NaN    320   35      55
# 163  150        MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# 161  149                  Dragonite    Dragon    Flying    600   91     134
# 44    39                 Jigglypuff    Normal     Fairy    270  115      45
# 138  128                     Tauros    Normal       NaN    490   75     100
# 157  145                     Zapdos  Electric    Flying    580   90      90
# 95    88                     Grimer    Poison       NaN    325   80      80
# 51    46                      Paras       Bug     Grass    285   35      70
# 126  117                     Seadra     Water       NaN    440   55      65
# ...

# %%
sample_gen_2 = pokemon[pokemon.Generation==2].sample(30)
sample_gen_2
# Out:
#        #                     Name    Type 1    Type 2  Total   HP  Attack  \
# 213  198                  Murkrow      Dark    Flying    405   60      85
# 261  242                  Blissey    Normal       NaN    540  255      10
# 189  175                   Togepi     Fairy       NaN    245   35      20
# 236  218                   Slugma      Fire       NaN    250   40      40
# 256  237                Hitmontop  Fighting       NaN    455   50      95
# 171  157               Typhlosion      Fire       NaN    534   78      84
# 259  240                    Magby      Fire       NaN    365   45      75
# 233  215                  Sneasel      Dark       Ice    430   55      95
# 216  201                    Unown   Psychic       NaN    336   48      72
# 260  241                  Miltank    Normal       NaN    490   95      80
# 262  243                   Raikou  Electric       NaN    580   90      85
# 190  176                  Togetic     Fairy    Flying    405   55      40
# ...

# %%
t_test_features(sample_gen_1, sample_gen_2)
# Out:
# {'HP': 0.8567048254736578,
#  'Attack': 0.4935720048105311,
#  'Defense': 0.42093028852185366,
#  'Sp. Atk': 0.8462922476759211,
#  'Sp. Def': 0.1405352037635294,
#  'Speed': 0.1401213333638077,
#  'Total': 0.9755636536126104}

# %% [markdown]
# #### What conclusions can you make?

# %% [markdown]
# I don't reject H0 in any of the tested features, so I can say that by mean they do have same stats.

# %% [markdown]
# #### Compare pokemons who have single type vs those having two types.

# %%
sample_1_type = pokemon[pokemon['Type 2'].isnull()].sample(30)
sample_1_type
# Out:
#        #                 Name    Type 1 Type 2  Total   HP  Attack  Defense  \
# 574  515              Panpour     Water    NaN    316   50      53       48
# 645  584            Vanilluxe       Ice    NaN    535   71      95       85
# 550  492    ShayminLand Forme     Grass    NaN    600  100     100      100
# 311  287              Slakoth    Normal    NaN    280   60      60       60
# 189  175               Togepi     Fairy    NaN    245   35      20       65
# 14    11              Metapod       Bug    NaN    205   50      20       55
# 129  120               Staryu     Water    NaN    340   30      45       55
# 31    26               Raichu  Electric    NaN    485   60      90       55
# 479  431              Glameow    Normal    NaN    310   49      55       42
# 687  626           Bouffalant    Normal    NaN    490   95     110       95
# 402  367              Huntail     Water    NaN    485   55     104      105
# ...

# %%
sample_2_type = pokemon[~pokemon['Type 2'].isnull()].sample(30)
sample_2_type
# Out:
#        #                   Name    Type 1    Type 2  Total   HP  Attack  \
# 1      2                Ivysaur     Grass    Poison    405   60      62
# 21    17              Pidgeotto    Normal    Flying    349   63      60
# 140  130               Gyarados     Water    Flying    540   95     125
# 370  338                Solrock      Rock   Psychic    440   70      95
# 766  696                 Tyrunt      Rock    Dragon    362   58      89
# 482  434                 Stunky    Poison      Dark    329   63      63
# 483  435               Skuntank    Poison      Dark    479  103      93
# 497  448                Lucario  Fighting     Steel    525   70     110
# 89    82               Magneton  Electric     Steel    465   50      60
# 133  124                   Jynx       Ice   Psychic    455   65      50
# 267  248              Tyranitar      Rock      Dark    600  100     134
# 437  392              Infernape      Fire  Fighting    534   76     104
# ...

# %%
t_test_features(sample_1_type, sample_2_type)
# Out:
# {'HP': 0.6947182883537857,
#  'Attack': 0.6353551593520244,
#  'Defense': 0.7688289188387574,
#  'Sp. Atk': 0.19186342883097565,
#  'Sp. Def': 0.4194000436895742,
#  'Speed': 0.12904323356645744,
#  'Total': 0.33624900006384006}

# %% [markdown]
# #### What conclusions can you make?

# %% [markdown]
# I don't reject H0 in any of the tested features, so I can say that by mean they do have same stats.

# %% [markdown]
# #### Now, we want to compare whether there are significant differences of `Attack` vs `Defense`  and  `Sp. Atk` vs `Sp. Def` of all pokemons. Please write your code below.
#
# *Hint: are you comparing different populations or the same population?*

# %%
# dependent variables testing
# H0: mu_a - mu_d = 0
# H1: mu_a - mu_d != 0
# 5% significance

st.ttest_rel(pokemon['Attack'], pokemon['Defense'])
# Out:
# TtestResult(statistic=4.325566393330478, pvalue=1.7140303479358558e-05, df=799)

# %%
# dependent variables testing
# H0: mu_spa - mu_spd = 0
# H1: mu_spa - mu_spd != 0
# 5% significance

st.ttest_rel(pokemon['Sp. Atk'], pokemon['Sp. Def'])
# Out:
# TtestResult(statistic=0.853986188453353, pvalue=0.3933685997548122, df=799)

# %% [markdown]
# #### What conclusions can you make?

# %% [markdown]
# In the first test (Attack vs Defense) I reject H0, so my conclusion is that there are significant differences between Attack and Defense in the pokemons.

# %% [markdown]
# In the second thest (Sp. Atk vs Sp. Def) I don't reject H0, so my conclusion is that there are not significant differences between Sp. Atk and Sp. Def in the pokemons.
